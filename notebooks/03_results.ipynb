# %% [markdown]
# # FarmTrack Results Visualization
#
# Evaluate inference results on test images, view IoU metrics, and inspect failure cases.

# %%
import os
import torch
import matplotlib.pyplot as plt

print("Ready to visualize predictions.")
