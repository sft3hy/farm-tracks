# %% [markdown]
# # FarmTrack Annotation Quality Check
#
# Use this notebook to review masks created in Label Studio or CVAT before using them for training.

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Add paths to the annotated data here
data_path = '../data/annotated/'
print(f"Annotation directory: {data_path}")
